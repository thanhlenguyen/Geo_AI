# %% [markdown]
# # Building Footprint Extraction for Kingdom Saudi Arabia
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/building_footprints_africa.ipynb)
#
# ## Install package
#
# To use the `geoai-py` package, ensure it is installed in your environment. Uncomment the command below if needed.

# %%
# %pip install geoai-py
# Out:
# Collecting geoai-py
#   Downloading geoai_py-0.5.5-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting albumentations (from geoai-py)
#   Using cached albumentations-2.0.5-py3-none-any.whl.metadata (41 kB)
# Collecting buildingregulariser (from geoai-py)
#   Downloading buildingregulariser-0.1.12-py3-none-any.whl.metadata (5.9 kB)
# Collecting contextily (from geoai-py)
#   Using cached contextily-1.6.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting geopandas (from geoai-py)
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting huggingface_hub (from geoai-py)
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Collecting jupyter-server-proxy (from geoai-py)
#   Using cached jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting leafmap (from geoai-py)
#   Downloading leafmap-0.43.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting localtileserver (from geoai-py)
#   Using cached localtileserver-0.10.6-py3-none-any.whl.metadata (5.2 kB)
# Collecting mapclassify (from geoai-py)
#   Using cached mapclassify-2.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting maplibre (from geoai-py)
#   Downloading maplibre-0.3.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting overturemaps (from geoai-py)
#   Using cached overturemaps-0.14.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting planetary-computer (from geoai-py)
#   Using cached planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting pystac-client (from geoai-py)
#   Using cached pystac_client-0.8.6-py3-none-any.whl.metadata (3.0 kB)
# Collecting rasterio (from geoai-py)
#   Using cached rasterio-1.4.3-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# Collecting rioxarray (from geoai-py)
#   Downloading rioxarray-0.19.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting scikit-image (from geoai-py)
#   Using cached scikit_image-0.25.2-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting scikit-learn (from geoai-py)
#   Using cached scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting torch (from geoai-py)
#   Using cached torch-2.6.0-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting torchgeo (from geoai-py)
#   Downloading torchgeo-0.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting torchinfo (from geoai-py)
#   Using cached torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Collecting tqdm (from geoai-py)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting transformers (from geoai-py)
#   Downloading transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Collecting numpy>=1.24.4 (from albumentations->geoai-py)
#   Downloading numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting scipy>=1.10.0 (from albumentations->geoai-py)
#   Using cached scipy-1.15.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting PyYAML (from albumentations->geoai-py)
#   Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting pydantic>=2.9.2 (from albumentations->geoai-py)
#   Downloading pydantic-2.11.3-py3-none-any.whl.metadata (65 kB)
# Collecting albucore==0.0.23 (from albumentations->geoai-py)
#   Using cached albucore-0.0.23-py3-none-any.whl.metadata (5.3 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations->geoai-py)
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting stringzilla>=3.10.4 (from albucore==0.0.23->albumentations->geoai-py)
#   Downloading stringzilla-3.12.5-cp312-cp312-win_amd64.whl.metadata (81 kB)
# Collecting simsimd>=5.9.2 (from albucore==0.0.23->albumentations->geoai-py)
#   Using cached simsimd-6.2.1-cp312-cp312-win_amd64.whl.metadata (67 kB)
# Collecting pyogrio>=0.7.2 (from geopandas->geoai-py)
#   Using cached pyogrio-0.10.0-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging in d:\git\geoai\.envs\lib\site-packages (from geopandas->geoai-py) (25.0)
# Collecting pandas>=1.4.0 (from geopandas->geoai-py)
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting pyproj>=3.3.0 (from geopandas->geoai-py)
#   Downloading pyproj-3.7.1-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas->geoai-py)
#   Downloading shapely-2.1.0-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Collecting geopy (from contextily->geoai-py)
#   Using cached geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting matplotlib (from contextily->geoai-py)
#   Using cached matplotlib-3.10.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting mercantile (from contextily->geoai-py)
#   Using cached mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting pillow (from contextily->geoai-py)
#   Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting requests (from contextily->geoai-py)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting joblib (from contextily->geoai-py)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting xyzservices (from contextily->geoai-py)
#   Using cached xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting filelock (from huggingface_hub->geoai-py)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub->geoai-py)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting typing-extensions>=3.7.4.3 (from huggingface_hub->geoai-py)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: colorama in d:\git\geoai\.envs\lib\site-packages (from tqdm->geoai-py) (0.4.6)
# Collecting aiohttp (from jupyter-server-proxy->geoai-py)
#   Downloading aiohttp-3.11.18-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Collecting jupyter-server>=1.24.0 (from jupyter-server-proxy->geoai-py)
#   Using cached jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->geoai-py)
#   Using cached simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tornado>=6.1.0 in d:\git\geoai\.envs\lib\site-packages (from jupyter-server-proxy->geoai-py) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in d:\git\geoai\.envs\lib\site-packages (from jupyter-server-proxy->geoai-py) (5.14.3)
# Collecting anywidget (from leafmap->geoai-py)
#   Downloading anywidget-0.9.18-py3-none-any.whl.metadata (8.9 kB)
# Collecting bqplot (from leafmap->geoai-py)
#   Using cached bqplot-0.12.44-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting colour (from leafmap->geoai-py)
#   Using cached colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Collecting duckdb (from leafmap->geoai-py)
#   Downloading duckdb-1.2.2-cp312-cp312-win_amd64.whl.metadata (995 bytes)
# Collecting folium (from leafmap->geoai-py)
#   Using cached folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting gdown (from leafmap->geoai-py)
#   Using cached gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting geojson (from leafmap->geoai-py)
#   Using cached geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting ipyevents (from leafmap->geoai-py)
#   Using cached ipyevents-2.0.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting ipyfilechooser (from leafmap->geoai-py)
#   Using cached ipyfilechooser-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyleaflet (from leafmap->geoai-py)
#   Using cached ipyleaflet-0.19.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting ipyvuetify (from leafmap->geoai-py)
#   Using cached ipyvuetify-1.11.1-py2.py3-none-any.whl.metadata (7.5 kB)
# Collecting ipywidgets (from leafmap->geoai-py)
#   Downloading ipywidgets-8.1.6-py3-none-any.whl.metadata (2.4 kB)
# Collecting plotly (from leafmap->geoai-py)
#   Using cached plotly-6.0.1-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: psutil in d:\git\geoai\.envs\lib\site-packages (from leafmap->geoai-py) (7.0.0)
# Collecting pyshp (from leafmap->geoai-py)
#   Using cached pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
# Collecting python-box (from leafmap->geoai-py)
#   Using cached python_box-7.3.2-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Collecting scooby (from leafmap->geoai-py)
#   Using cached scooby-0.10.0-py3-none-any.whl.metadata (15 kB)
# Collecting whiteboxgui (from leafmap->geoai-py)
#   Using cached whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting click (from localtileserver->geoai-py)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting flask<4,>=2.0.0 (from localtileserver->geoai-py)
#   Using cached flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting Flask-Caching (from localtileserver->geoai-py)
#   Using cached Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver->geoai-py)
#   Using cached flask_cors-5.0.1-py3-none-any.whl.metadata (961 bytes)
# Collecting flask-restx>=1.3.0 (from localtileserver->geoai-py)
#   Using cached flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver->geoai-py)
#   Downloading rio_tiler-7.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting rio-cogeo (from localtileserver->geoai-py)
#   Using cached rio_cogeo-5.4.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting server-thread (from localtileserver->geoai-py)
#   Using cached server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting werkzeug (from localtileserver->geoai-py)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting networkx>=2.7 (from mapclassify->geoai-py)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->geoai-py)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting branca (from maplibre->geoai-py)
#   Using cached branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting eval-type-backport (from maplibre->geoai-py)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting jinja2>=3.1.5 (from maplibre->geoai-py)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting pyarrow>=15.0.2 (from overturemaps->geoai-py)
#   Using cached pyarrow-19.0.1-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting pystac>=1.0.0 (from planetary-computer->geoai-py)
#   Downloading pystac-1.13.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pytz>=2020.5 (from planetary-computer->geoai-py)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting python-dotenv (from planetary-computer->geoai-py)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\git\geoai\.envs\lib\site-packages (from pystac-client->geoai-py) (2.9.0.post0)
# Collecting affine (from rasterio->geoai-py)
#   Using cached affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs (from rasterio->geoai-py)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting certifi (from rasterio->geoai-py)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting cligj>=0.5 (from rasterio->geoai-py)
#   Using cached cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio->geoai-py)
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting pyparsing (from rasterio->geoai-py)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting xarray>=2024.7.0 (from rioxarray->geoai-py)
#   Downloading xarray-2025.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->geoai-py)
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->geoai-py)
#   Downloading tifffile-2025.3.30-py3-none-any.whl.metadata (32 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->geoai-py)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting setuptools (from torch->geoai-py)
#   Downloading setuptools-79.0.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting sympy==1.13.1 (from torch->geoai-py)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch->geoai-py)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting einops>=0.3 (from torchgeo->geoai-py)
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting fiona>=1.8.22 (from torchgeo->geoai-py)
#   Using cached fiona-1.10.1-cp312-cp312-win_amd64.whl.metadata (58 kB)
# Collecting kornia>=0.7.4 (from torchgeo->geoai-py)
#   Using cached kornia-0.8.0-py2.py3-none-any.whl.metadata (17 kB)
# Collecting lightly!=1.4.26,>=1.4.5 (from torchgeo->geoai-py)
#   Using cached lightly-1.5.19-py3-none-any.whl.metadata (36 kB)
# Collecting lightning!=2.3.*,!=2.5.0,>=2 (from lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Using cached lightning-2.5.1-py3-none-any.whl.metadata (39 kB)
# Collecting rtree>=1.0.1 (from torchgeo->geoai-py)
#   Using cached rtree-1.4.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Collecting segmentation-models-pytorch>=0.3.3 (from torchgeo->geoai-py)
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting timm>=0.9.2 (from torchgeo->geoai-py)
#   Using cached timm-1.0.15-py3-none-any.whl.metadata (52 kB)
# Collecting torchmetrics>=1.2 (from torchgeo->geoai-py)
#   Downloading torchmetrics-1.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting torchvision>=0.15.1 (from torchgeo->geoai-py)
#   Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting regex!=2019.12.17 (from transformers->geoai-py)
#   Using cached regex-2024.11.6-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers->geoai-py)
#   Using cached tokenizers-0.21.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers->geoai-py)
#   Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Collecting itsdangerous>=2.2 (from flask<4,>=2.0.0->localtileserver->geoai-py)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.9 (from flask<4,>=2.0.0->localtileserver->geoai-py)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver->geoai-py)
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Collecting jsonschema (from flask-restx>=1.3.0->localtileserver->geoai-py)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting importlib-resources (from flask-restx>=1.3.0->localtileserver->geoai-py)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=3.1.5->maplibre->geoai-py)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Collecting anyio>=3.1.0 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in d:\git\geoai\.envs\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\git\geoai\.envs\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (5.7.2)
# Collecting jupyter-events>=0.11.0 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting overrides>=5.0 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Downloading pywinpty-2.0.15-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: pyzmq>=24 in d:\git\geoai\.envs\lib\site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (26.4.0)
# Collecting send2trash>=1.8.2 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting kornia_rs>=0.1.0 (from kornia>=0.7.4->torchgeo->geoai-py)
#   Using cached kornia_rs-0.1.8-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting hydra-core>=1.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightly_utils~=0.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Using cached lightly_utils-0.0.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.10 in d:\git\geoai\.envs\lib\site-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (1.17.0)
# Collecting pytorch_lightning>=1.0.4 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Using cached pytorch_lightning-2.5.1-py3-none-any.whl.metadata (20 kB)
# Collecting urllib3>=1.25.3 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting aenum>=3.1.11 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Using cached aenum-3.1.15-py3-none-any.whl.metadata (3.7 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting packaging (from geopandas->geoai-py)
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting jsonargparse<5.0,>=4.27.7 (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Downloading jsonargparse-4.38.0-py3-none-any.whl.metadata (12 kB)
# Collecting omegaconf<3.0,>=2.2.3 (from lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting rich<14.0,>=12.3.0 (from lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tensorboardX<3.0,>=2.2 (from lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting bitsandbytes<1.0,>=0.45.2 (from lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Downloading bitsandbytes-0.45.5-py3-none-win_amd64.whl.metadata (5.1 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->contextily->geoai-py)
#   Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->contextily->geoai-py)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->contextily->geoai-py)
#   Downloading fonttools-4.57.0-cp312-cp312-win_amd64.whl.metadata (104 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->contextily->geoai-py)
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.4.0->geopandas->geoai-py)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9.2->albumentations->geoai-py)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.1 (from pydantic>=2.9.2->albumentations->geoai-py)
#   Downloading pydantic_core-2.33.1-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2.9.2->albumentations->geoai-py)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests->contextily->geoai-py)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests->contextily->geoai-py)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->jupyter-server-proxy->geoai-py)
#   Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl.metadata (74 kB)
# Collecting psygnal>=0.8.1 (from anywidget->leafmap->geoai-py)
#   Using cached psygnal-0.12.0-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: comm>=0.1.3 in d:\git\geoai\.envs\lib\site-packages (from ipywidgets->leafmap->geoai-py) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in d:\git\geoai\.envs\lib\site-packages (from ipywidgets->leafmap->geoai-py) (9.1.0)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->leafmap->geoai-py)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.14 (from ipywidgets->leafmap->geoai-py)
#   Downloading jupyterlab_widgets-3.0.14-py3-none-any.whl.metadata (4.1 kB)
# Collecting traittypes>=0.0.6 (from bqplot->leafmap->geoai-py)
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting cachelib>=0.9.0 (from Flask-Caching->localtileserver->geoai-py)
#   Using cached cachelib-0.13.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting beautifulsoup4 (from gdown->leafmap->geoai-py)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy->contextily->geoai-py)
#   Using cached geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting jupyter-leaflet<0.20,>=0.19 (from ipyleaflet->leafmap->geoai-py)
#   Using cached jupyter_leaflet-0.19.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting ipyvue<2,>=1.7 (from ipyvuetify->leafmap->geoai-py)
#   Using cached ipyvue-1.11.2-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting narwhals>=1.15.1 (from plotly->leafmap->geoai-py)
#   Downloading narwhals-1.35.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting morecantile<7.0,>=5.0 (from rio-cogeo->localtileserver->geoai-py)
#   Using cached morecantile-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting cachetools (from rio-tiler->localtileserver->geoai-py)
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting color-operations (from rio-tiler->localtileserver->geoai-py)
#   Downloading color_operations-0.2.0-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Collecting httpx (from rio-tiler->localtileserver->geoai-py)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting numexpr (from rio-tiler->localtileserver->geoai-py)
#   Using cached numexpr-2.10.2-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Collecting uvicorn (from server-thread->localtileserver->geoai-py)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting ipytree (from whiteboxgui->leafmap->geoai-py)
#   Using cached ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Collecting whitebox (from whiteboxgui->leafmap->geoai-py)
#   Using cached whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Collecting sniffio>=1.1 (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Requirement already satisfied: decorator in d:\git\geoai\.envs\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in d:\git\geoai\.envs\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\git\geoai\.envs\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.19.2)
# Requirement already satisfied: matplotlib-inline in d:\git\geoai\.envs\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\git\geoai\.envs\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in d:\git\geoai\.envs\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (2.19.1)
# Requirement already satisfied: stack_data in d:\git\geoai\.envs\lib\site-packages (from ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.6.3)
# Collecting docstring-parser>=0.15 (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Using cached docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting typeshed-client>=2.1.0 (from jsonargparse[signatures]<5.0,>=4.27.7; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Using cached typeshed_client-2.7.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->flask-restx>=1.3.0->localtileserver->geoai-py)
#   Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema->flask-restx>=1.3.0->localtileserver->geoai-py)
#   Using cached referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->flask-restx>=1.3.0->localtileserver->geoai-py)
#   Downloading rpds_py-0.24.0-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: platformdirs>=2.5 in d:\git\geoai\.envs\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (4.3.7)
# Requirement already satisfied: pywin32>=300 in d:\git\geoai\.envs\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py) (310)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached mistune-3.1.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting protobuf>=3.20 (from tensorboardX<3.0,>=2.2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting soupsieve>1.2 (from beautifulsoup4->gdown->leafmap->geoai-py)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Collecting httpcore==1.* (from httpx->rio-tiler->localtileserver->geoai-py)
#   Downloading httpcore-1.0.8-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->rio-tiler->localtileserver->geoai-py)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]->gdown->leafmap->geoai-py)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\git\geoai\.envs\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.8.4)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo->geoai-py)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: wcwidth in d:\git\geoai\.envs\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.2.13)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Downloading cffi-1.17.1-cp312-cp312-win_amd64.whl.metadata (1.6 kB)
# Requirement already satisfied: executing>=1.2.0 in d:\git\geoai\.envs\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\git\geoai\.envs\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (3.0.0)
# Requirement already satisfied: pure-eval in d:\git\geoai\.envs\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->leafmap->geoai-py) (0.2.3)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py)
#   Using cached types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Downloading geoai_py-0.5.5-py2.py3-none-any.whl (130 kB)
# Using cached albumentations-2.0.5-py3-none-any.whl (290 kB)
# Using cached albucore-0.0.23-py3-none-any.whl (14 kB)
# Downloading buildingregulariser-0.1.12-py3-none-any.whl (19 kB)
# Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# Using cached contextily-1.6.2-py3-none-any.whl (17 kB)
# Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached jupyter_server_proxy-4.4.0-py3-none-any.whl (37 kB)
# Downloading leafmap-0.43.6-py2.py3-none-any.whl (537 kB)
#    ---------------------------------------- 0.0/537.2 kB ? eta -:--:--
#    ---------------------------------------- 537.2/537.2 kB 3.5 MB/s eta 0:00:00
# Using cached localtileserver-0.10.6-py3-none-any.whl (17.1 MB)
# Using cached mapclassify-2.8.1-py3-none-any.whl (59 kB)
# Using cached scikit_learn-1.6.1-cp312-cp312-win_amd64.whl (11.1 MB)
# Downloading maplibre-0.3.3-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    -------------------------------- ------- 1.0/1.3 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 5.2 MB/s eta 0:00:00
# Using cached overturemaps-0.14.0-py3-none-any.whl (9.9 kB)
# Using cached planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Using cached pystac_client-0.8.6-py3-none-any.whl (41 kB)
# Using cached rasterio-1.4.3-cp312-cp312-win_amd64.whl (25.4 MB)
# Downloading rioxarray-0.19.0-py3-none-any.whl (62 kB)
# Using cached scikit_image-0.25.2-cp312-cp312-win_amd64.whl (12.9 MB)
# Using cached torch-2.6.0-cp312-cp312-win_amd64.whl (204.1 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Downloading torchgeo-0.7.0-py3-none-any.whl (604 kB)
#    ---------------------------------------- 0.0/605.0 kB ? eta -:--:--
#    ---------------------------------------- 605.0/605.0 kB 4.4 MB/s eta 0:00:00
# Using cached torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Downloading transformers-4.51.3-py3-none-any.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/10.4 MB 5.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/10.4 MB 5.3 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/10.4 MB 5.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.4 MB 5.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.8/10.4 MB 5.6 MB/s eta 0:00:01
#    -------------------------- ------------- 6.8/10.4 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 8.1/10.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.9/10.4 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.4 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 5.4 MB/s eta 0:00:00
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached fiona-1.10.1-cp312-cp312-win_amd64.whl (24.5 MB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Using cached flask-3.1.0-py3-none-any.whl (102 kB)
# Using cached flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached jupyter_server-2.15.0-py3-none-any.whl (385 kB)
# Using cached kornia-0.8.0-py2.py3-none-any.whl (1.1 MB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached lightly-1.5.19-py3-none-any.whl (850 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Using cached lightning-2.5.1-py3-none-any.whl (818 kB)
# Using cached matplotlib-3.10.1-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Downloading numpy-2.2.5-cp312-cp312-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 5.6 MB/s eta 0:00:03
#    ------- -------------------------------- 2.4/12.6 MB 5.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.6 MB 6.1 MB/s eta 0:00:02
#    --------------- ------------------------ 5.0/12.6 MB 6.0 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.6 MB 5.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.6 MB 5.6 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.6 MB 5.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 5.3 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 5.2 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.6 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.6 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 4.9 MB/s eta 0:00:00
# Using cached opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl (39.4 MB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 5.2 MB/s eta 0:00:00
# Using cached pyarrow-19.0.1-cp312-cp312-win_amd64.whl (25.3 MB)
# Downloading pydantic-2.11.3-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.1-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/2.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.9 MB/s eta 0:00:00
# Using cached pyogrio-0.10.0-cp312-cp312-win_amd64.whl (16.2 MB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading pyproj-3.7.1-cp312-cp312-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.3 MB 5.6 MB/s eta 0:00:01
#    ------------- -------------------------- 2.1/6.3 MB 5.6 MB/s eta 0:00:01
#    -------------------- ------------------- 3.1/6.3 MB 5.3 MB/s eta 0:00:01
#    -------------------------- ------------- 4.2/6.3 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.5/6.3 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 5.3 MB/s eta 0:00:00
# Downloading pystac-1.13.0-py3-none-any.whl (206 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Using cached regex-2024.11.6-cp312-cp312-win_amd64.whl (273 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached rtree-1.4.0-py3-none-win_amd64.whl (385 kB)
# Using cached safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Using cached scipy-1.15.2-cp312-cp312-win_amd64.whl (40.9 MB)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
# Downloading shapely-2.1.0-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------ --------------- 1.0/1.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 5.8 MB/s eta 0:00:00
# Using cached simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tifffile-2025.3.30-py3-none-any.whl (226 kB)
# Using cached timm-1.0.15-py3-none-any.whl (2.4 MB)
# Using cached tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
# Downloading torchmetrics-1.7.1-py3-none-any.whl (961 kB)
#    ---------------------------------------- 0.0/961.5 kB ? eta -:--:--
#    ---------------------------------------- 961.5/961.5 kB 5.0 MB/s eta 0:00:00
# Using cached torchvision-0.21.0-cp312-cp312-win_amd64.whl (1.6 MB)
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading xarray-2025.3.1-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------------------------ --------------- 0.8/1.3 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 4.6 MB/s eta 0:00:00
# Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading aiohttp-3.11.18-cp312-cp312-win_amd64.whl (439 kB)
# Downloading anywidget-0.9.18-py3-none-any.whl (220 kB)
# Downloading ipywidgets-8.1.6-py3-none-any.whl (139 kB)
# Using cached bqplot-0.12.44-py2.py3-none-any.whl (1.2 MB)
# Using cached branca-0.8.1-py3-none-any.whl (26 kB)
# Using cached colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Downloading duckdb-1.2.2-cp312-cp312-win_amd64.whl (11.4 MB)
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.4 MB 5.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.4 MB 5.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.4/11.4 MB 5.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.4 MB 5.7 MB/s eta 0:00:02
#    -------------------- ------------------- 5.8/11.4 MB 5.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.8/11.4 MB 5.7 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.4 MB 5.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.4 MB 5.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.4 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.4/11.4 MB 5.5 MB/s eta 0:00:00
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Using cached flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Using cached folium-0.19.5-py2.py3-none-any.whl (110 kB)
# Using cached gdown-5.2.0-py3-none-any.whl (18 kB)
# Using cached geojson-3.2.0-py3-none-any.whl (15 kB)
# Using cached geopy-2.4.1-py3-none-any.whl (125 kB)
# Using cached ipyevents-2.0.2-py3-none-any.whl (101 kB)
# Using cached ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Using cached ipyleaflet-0.19.2-py3-none-any.whl (31 kB)
# Using cached xyzservices-2025.1.0-py3-none-any.whl (88 kB)
# Using cached ipyvuetify-1.11.1-py2.py3-none-any.whl (7.7 MB)
# Using cached mercantile-1.2.1-py3-none-any.whl (14 kB)
# Using cached plotly-6.0.1-py3-none-any.whl (14.8 MB)
# Using cached pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Using cached python_box-7.3.2-cp312-cp312-win_amd64.whl (1.2 MB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Using cached rio_cogeo-5.4.1-py3-none-any.whl (20 kB)
# Downloading rio_tiler-7.6.0-py3-none-any.whl (268 kB)
# Using cached scooby-0.10.0-py3-none-any.whl (18 kB)
# Using cached server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading setuptools-79.0.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    --------------------------------- ------ 1.0/1.3 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 5.8 MB/s eta 0:00:00
# Using cached whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
# Using cached aenum-3.1.15-py3-none-any.whl (137 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading bitsandbytes-0.45.5-py3-none-win_amd64.whl (75.4 MB)
#    ---------------------------------------- 0.0/75.4 MB ? eta -:--:--
#     --------------------------------------- 1.0/75.4 MB 6.3 MB/s eta 0:00:12
#    - -------------------------------------- 2.4/75.4 MB 6.1 MB/s eta 0:00:12
#    - -------------------------------------- 3.4/75.4 MB 5.8 MB/s eta 0:00:13
#    -- ------------------------------------- 4.7/75.4 MB 5.8 MB/s eta 0:00:13
#    --- ------------------------------------ 6.0/75.4 MB 5.7 MB/s eta 0:00:13
#    --- ------------------------------------ 7.1/75.4 MB 5.7 MB/s eta 0:00:12
#    ---- ----------------------------------- 8.1/75.4 MB 5.6 MB/s eta 0:00:13
#    ----- ---------------------------------- 9.4/75.4 MB 5.7 MB/s eta 0:00:12
#    ----- ---------------------------------- 10.7/75.4 MB 5.7 MB/s eta 0:00:12
#    ------ --------------------------------- 11.8/75.4 MB 5.8 MB/s eta 0:00:12
#    ------ --------------------------------- 12.8/75.4 MB 5.6 MB/s eta 0:00:12
#    ------- -------------------------------- 14.2/75.4 MB 5.6 MB/s eta 0:00:11
#    -------- ------------------------------- 15.5/75.4 MB 5.7 MB/s eta 0:00:11
#    -------- ------------------------------- 16.8/75.4 MB 5.7 MB/s eta 0:00:11
#    --------- ------------------------------ 17.8/75.4 MB 5.7 MB/s eta 0:00:11
#    ---------- ----------------------------- 19.1/75.4 MB 5.6 MB/s eta 0:00:10
#    ---------- ----------------------------- 19.9/75.4 MB 5.6 MB/s eta 0:00:10
#    ----------- ---------------------------- 21.0/75.4 MB 5.5 MB/s eta 0:00:10
#    ----------- ---------------------------- 21.8/75.4 MB 5.5 MB/s eta 0:00:10
#    ------------ --------------------------- 22.8/75.4 MB 5.5 MB/s eta 0:00:10
#    ------------ --------------------------- 24.1/75.4 MB 5.5 MB/s eta 0:00:10
#    ------------- -------------------------- 25.2/75.4 MB 5.5 MB/s eta 0:00:10
#    ------------- -------------------------- 26.2/75.4 MB 5.5 MB/s eta 0:00:10
#    -------------- ------------------------- 27.5/75.4 MB 5.5 MB/s eta 0:00:09
#    --------------- ------------------------ 28.8/75.4 MB 5.5 MB/s eta 0:00:09
#    --------------- ------------------------ 29.9/75.4 MB 5.5 MB/s eta 0:00:09
#    ---------------- ----------------------- 31.2/75.4 MB 5.5 MB/s eta 0:00:09
#    ----------------- ---------------------- 32.2/75.4 MB 5.5 MB/s eta 0:00:08
#    ----------------- ---------------------- 33.6/75.4 MB 5.5 MB/s eta 0:00:08
#    ------------------ --------------------- 34.9/75.4 MB 5.5 MB/s eta 0:00:08
#    ------------------- -------------------- 35.9/75.4 MB 5.6 MB/s eta 0:00:08
#    ------------------- -------------------- 37.0/75.4 MB 5.6 MB/s eta 0:00:07
#    -------------------- ------------------- 38.3/75.4 MB 5.5 MB/s eta 0:00:07
#    -------------------- ------------------- 39.3/75.4 MB 5.5 MB/s eta 0:00:07
#    --------------------- ------------------ 40.4/75.4 MB 5.5 MB/s eta 0:00:07
#    --------------------- ------------------ 41.4/75.4 MB 5.5 MB/s eta 0:00:07
#    ---------------------- ----------------- 42.5/75.4 MB 5.5 MB/s eta 0:00:07
#    ----------------------- ---------------- 43.5/75.4 MB 5.5 MB/s eta 0:00:06
#    ----------------------- ---------------- 44.6/75.4 MB 5.5 MB/s eta 0:00:06
#    ------------------------ --------------- 45.6/75.4 MB 5.5 MB/s eta 0:00:06
#    ------------------------ --------------- 46.9/75.4 MB 5.5 MB/s eta 0:00:06
#    ------------------------- -------------- 48.2/75.4 MB 5.5 MB/s eta 0:00:05
#    -------------------------- ------------- 49.3/75.4 MB 5.5 MB/s eta 0:00:05
#    -------------------------- ------------- 50.6/75.4 MB 5.5 MB/s eta 0:00:05
#    --------------------------- ------------ 51.6/75.4 MB 5.5 MB/s eta 0:00:05
#    --------------------------- ------------ 52.7/75.4 MB 5.5 MB/s eta 0:00:05
#    ---------------------------- ----------- 54.0/75.4 MB 5.5 MB/s eta 0:00:04
#    ----------------------------- ---------- 55.1/75.4 MB 5.5 MB/s eta 0:00:04
#    ----------------------------- ---------- 56.4/75.4 MB 5.5 MB/s eta 0:00:04
#    ------------------------------ --------- 57.4/75.4 MB 5.5 MB/s eta 0:00:04
#    ------------------------------ --------- 58.5/75.4 MB 5.5 MB/s eta 0:00:04
#    ------------------------------- -------- 59.5/75.4 MB 5.5 MB/s eta 0:00:03
#    -------------------------------- ------- 60.6/75.4 MB 5.5 MB/s eta 0:00:03
#    -------------------------------- ------- 61.9/75.4 MB 5.5 MB/s eta 0:00:03
#    --------------------------------- ------ 63.2/75.4 MB 5.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 64.2/75.4 MB 5.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 65.3/75.4 MB 5.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 66.3/75.4 MB 5.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 67.6/75.4 MB 5.5 MB/s eta 0:00:02
#    ------------------------------------ --- 68.7/75.4 MB 5.5 MB/s eta 0:00:02
#    ------------------------------------ --- 69.7/75.4 MB 5.5 MB/s eta 0:00:02
#    ------------------------------------- -- 70.8/75.4 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 71.8/75.4 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 72.9/75.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  74.2/75.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  75.0/75.4 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 75.4/75.4 MB 5.4 MB/s eta 0:00:00
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached cachelib-0.13.0-py3-none-any.whl (20 kB)
# Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.9 MB/s eta 0:00:00
# Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl (120 kB)
# Using cached geographiclib-2.0-py3-none-any.whl (40 kB)
# Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jsonargparse-4.38.0-py3-none-any.whl (219 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Using cached jupyter_leaflet-0.19.2-py3-none-any.whl (1.1 MB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading jupyterlab_widgets-3.0.14-py3-none-any.whl (213 kB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached kornia_rs-0.1.8-cp312-cp312-win_amd64.whl (1.7 MB)
# Using cached lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Using cached morecantile-6.2.0-py3-none-any.whl (49 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl (38 kB)
# Downloading narwhals-1.35.0-py3-none-any.whl (325 kB)
# Using cached nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached prometheus_client-0.21.1-py3-none-any.whl (54 kB)
# Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl (44 kB)
# Using cached psygnal-0.12.0-cp312-cp312-win_amd64.whl (381 kB)
# Using cached pytorch_lightning-2.5.1-py3-none-any.whl (822 kB)
# Downloading pywinpty-2.0.15-cp312-cp312-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ----------------------------- ---------- 1.0/1.4 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 5.6 MB/s eta 0:00:00
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached simsimd-6.2.1-cp312-cp312-win_amd64.whl (87 kB)
# Downloading stringzilla-3.12.5-cp312-cp312-win_amd64.whl (80 kB)
# Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.2 MB 11.2 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.6 MB/s eta 0:00:00
# Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl (92 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading color_operations-0.2.0-cp312-cp312-win_amd64.whl (133 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.8-py3-none-any.whl (78 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
# Using cached numexpr-2.10.2-cp312-cp312-win_amd64.whl (145 kB)
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Using cached whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
# Using cached bleach-6.2.0-py3-none-any.whl (163 kB)
# Using cached docstring_parser-0.16-py3-none-any.whl (36 kB)
# Using cached fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mistune-3.1.3-py3-none-any.whl (53 kB)
# Using cached nbclient-0.10.2-py3-none-any.whl (25 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl (431 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Using cached referencing-0.36.2-py3-none-any.whl (26 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rpds_py-0.24.0-cp312-cp312-win_amd64.whl (239 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Using cached typeshed_client-2.7.0-py3-none-any.whl (624 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading cffi-1.17.1-cp312-cp312-win_amd64.whl (181 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Using cached webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, stringzilla, simsimd, pytz, mpmath, fastjsonschema, colour, antlr4-python3-runtime, aniso8601, aenum, xyzservices, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, tzdata, typing-extensions, types-python-dateutil, traittypes, tqdm, torchinfo, tinycss2, threadpoolctl, sympy, soupsieve, sniffio, simpervisor, setuptools, send2trash, scooby, safetensors, rtree, rpds-py, rfc3986-validator, rfc3339-validator, regex, PyYAML, pywinpty, python-json-logger, python-dotenv, python-box, PySocks, pyshp, pyparsing, pycparser, pyarrow, psygnal, protobuf, propcache, prometheus-client, pillow, pandocfilters, packaging, overrides, numpy, networkx, narwhals, multidict, mistune, mdurl, MarkupSafe, kornia_rs, kiwisolver, jupyterlab_widgets, jupyterlab-pygments, jupyter-leaflet, jsonpointer, joblib, itsdangerous, importlib-resources, idna, h11, geojson, geographiclib, fsspec, frozenlist, fqdn, fonttools, filelock, eval-type-backport, einops, duckdb, docstring-parser, defusedxml, cycler, click, charset-normalizer, certifi, cachetools, cachelib, blinker, bleach, attrs, annotated-types, aiohappyeyeballs, affine, yarl, whitebox, werkzeug, uvicorn, typing-inspection, typeshed-client, tifffile, terminado, tensorboardX, shapely, scipy, requests, referencing, pystac, pyproj, pyogrio, pydantic-core, plotly, pandas, opencv-python-headless, omegaconf, numexpr, mercantile, markdown-it-py, lightning-utilities, lightly_utils, lazy-loader, jsonargparse, jinja2, imageio, httpcore, geopy, contourpy, color-operations, cligj, click-plugins, cffi, beautifulsoup4, arrow, anyio, aiosignal, xarray, torch, server-thread, scikit-learn, scikit-image, rich, rasterio, pydantic, overturemaps, matplotlib, jupyter-server-terminals, jsonschema-specifications, isoduration, ipywidgets, hydra-core, huggingface_hub, httpx, geopandas, flask, fiona, branca, argon2-cffi-bindings, albucore, aiohttp, torchvision, torchmetrics, tokenizers, rioxarray, morecantile, maplibre, mapclassify, kornia, jsonschema, ipyvue, ipytree, ipyleaflet, ipyfilechooser, ipyevents, gdown, folium, flask-cors, Flask-Caching, contextily, buildingregulariser, bqplot, bitsandbytes, argon2-cffi, anywidget, albumentations, whiteboxgui, transformers, timm, rio-tiler, rio-cogeo, pytorch_lightning, nbformat, ipyvuetify, flask-restx, segmentation-models-pytorch, pystac-client, nbclient, localtileserver, lightning, lightly, jupyter-events, planetary-computer, nbconvert, leafmap, torchgeo, jupyter-server, jupyter-server-proxy, geoai-py
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed Flask-Caching-2.3.1 MarkupSafe-3.0.2 PySocks-1.7.1 PyYAML-6.0.2 aenum-3.1.15 affine-2.4.0 aiohappyeyeballs-2.6.1 aiohttp-3.11.18 aiosignal-1.3.2 albucore-0.0.23 albumentations-2.0.5 aniso8601-10.0.1 annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 anyio-4.9.0 anywidget-0.9.18 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 attrs-25.3.0 beautifulsoup4-4.13.4 bitsandbytes-0.45.5 bleach-6.2.0 blinker-1.9.0 bqplot-0.12.44 branca-0.8.1 buildingregulariser-0.1.12 cachelib-0.13.0 cachetools-5.5.2 certifi-2025.1.31 cffi-1.17.1 charset-normalizer-3.4.1 click-8.1.8 click-plugins-1.1.1 cligj-0.7.2 color-operations-0.2.0 colour-0.1.5 contextily-1.6.2 contourpy-1.3.2 cycler-0.12.1 defusedxml-0.7.1 docstring-parser-0.16 duckdb-1.2.2 einops-0.8.1 eval-type-backport-0.2.2 fastjsonschema-2.21.1 filelock-3.18.0 fiona-1.10.1 flask-3.1.0 flask-cors-5.0.1 flask-restx-1.3.0 folium-0.19.5 fonttools-4.57.0 fqdn-1.5.1 frozenlist-1.6.0 fsspec-2025.3.2 gdown-5.2.0 geoai-py-0.5.5 geographiclib-2.0 geojson-3.2.0 geopandas-1.0.1 geopy-2.4.1 h11-0.14.0 httpcore-1.0.8 httpx-0.28.1 huggingface_hub-0.30.2 hydra-core-1.3.2 idna-3.10 imageio-2.37.0 importlib-resources-6.5.2 ipyevents-2.0.2 ipyfilechooser-0.6.0 ipyleaflet-0.19.2 ipytree-0.2.2 ipyvue-1.11.2 ipyvuetify-1.11.1 ipywidgets-8.1.6 isoduration-20.11.0 itsdangerous-2.2.0 jinja2-3.1.6 joblib-1.4.2 jsonargparse-4.38.0 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter-events-0.12.0 jupyter-leaflet-0.19.2 jupyter-server-2.15.0 jupyter-server-proxy-4.4.0 jupyter-server-terminals-0.5.3 jupyterlab-pygments-0.3.0 jupyterlab_widgets-3.0.14 kiwisolver-1.4.8 kornia-0.8.0 kornia_rs-0.1.8 lazy-loader-0.4 leafmap-0.43.6 lightly-1.5.19 lightly_utils-0.0.2 lightning-2.5.1 lightning-utilities-0.14.3 localtileserver-0.10.6 mapclassify-2.8.1 maplibre-0.3.3 markdown-it-py-3.0.0 matplotlib-3.10.1 mdurl-0.1.2 mercantile-1.2.1 mistune-3.1.3 morecantile-6.2.0 mpmath-1.3.0 multidict-6.4.3 narwhals-1.35.0 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 networkx-3.4.2 numexpr-2.10.2 numpy-2.2.5 omegaconf-2.3.0 opencv-python-headless-4.11.0.86 overrides-7.7.0 overturemaps-0.14.0 packaging-24.2 pandas-2.2.3 pandocfilters-1.5.1 pillow-11.2.1 planetary-computer-1.0.0 plotly-6.0.1 prometheus-client-0.21.1 propcache-0.3.1 protobuf-6.30.2 psygnal-0.12.0 pyarrow-19.0.1 pycparser-2.22 pydantic-2.11.3 pydantic-core-2.33.1 pyogrio-0.10.0 pyparsing-3.2.3 pyproj-3.7.1 pyshp-2.3.1 pystac-1.13.0 pystac-client-0.8.6 python-box-7.3.2 python-dotenv-1.1.0 python-json-logger-3.3.0 pytorch_lightning-2.5.1 pytz-2025.2 pywinpty-2.0.15 rasterio-1.4.3 referencing-0.36.2 regex-2024.11.6 requests-2.32.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rich-13.9.4 rio-cogeo-5.4.1 rio-tiler-7.6.0 rioxarray-0.19.0 rpds-py-0.24.0 rtree-1.4.0 safetensors-0.5.3 scikit-image-0.25.2 scikit-learn-1.6.1 scipy-1.15.2 scooby-0.10.0 segmentation-models-pytorch-0.5.0 send2trash-1.8.3 server-thread-0.3.0 setuptools-79.0.0 shapely-2.1.0 simpervisor-1.0.0 simsimd-6.2.1 sniffio-1.3.1 soupsieve-2.7 stringzilla-3.12.5 sympy-1.13.1 tensorboardX-2.6.2.2 terminado-0.18.1 threadpoolctl-3.6.0 tifffile-2025.3.30 timm-1.0.15 tinycss2-1.4.0 tokenizers-0.21.1 torch-2.6.0 torchgeo-0.7.0 torchinfo-1.8.0 torchmetrics-1.7.1 torchvision-0.21.0 tqdm-4.67.1 traittypes-0.2.1 transformers-4.51.3 types-python-dateutil-2.9.0.20241206 typeshed-client-2.7.0 typing-extensions-4.13.2 typing-inspection-0.4.0 tzdata-2025.2 uri-template-1.3.0 urllib3-2.4.0 uvicorn-0.34.2 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 werkzeug-3.1.3 whitebox-2.3.6 whiteboxgui-2.3.0 widgetsnbextension-4.0.14 xarray-2025.3.1 xyzservices-2025.1.0 yarl-1.20.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import libraries

# %%
import geoai

# %% [markdown]
# ## Download sample data

# %%
# raster_url = "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/buildings_africa.tif"

# %%
input_raster = r'D:\Git\geoai\examples\KSARiyadh_PNeo_20210526.tif'

# %% [markdown]
# ## Initialize the model

# %%
extractor = geoai.BuildingFootprintExtractor()
# Out:
# Model path not specified, downloading from Hugging Face...
# building_footprints_usa.pth:   0%|          | 0.00/176M [00:00<?, ?B/s]
# Model downloaded to: C:\Users\MININT-HNM8Q5T-local\.cache\huggingface\hub\models--giswqs--geoai\snapshots\75788bf6253e967a91b9576b1620949a3b939820\building_footprints_usa.pth
# Model loaded successfully

# %% [markdown]
# ## Extract building footprints

# %%
masks_path = extractor.generate_masks(
    input_raster,
    output_dir="building_masks.tif",
    min_object_area=1000,
    confidence_threshold=0.5,
    threshold=0.5,
)
# Out:
# Dataset initialized with 47 rows and 47 columns of chips
# Image dimensions: 17883 x 17767 pixels
# Chip size: 512 x 512 pixels
# Overlap: 25.0% (stride_x=384, stride_y=384)
# CRS: EPSG:3857
# Processing raster with 553 batches
# 100%|██████████| 553/553 [1:29:13<00:00,  9.68s/it]
# Masks with confidence values saved to D:\Git\geoai\examples\KSARiyadh_PNeo_20210526_masks_conf.tif

# %%
geoai.view_raster(masks_path, opacity=0.7, colormap="tab20", basemap=input_raster)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3bf3c7eb6093ca990b71ca9c0127686 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3bf3c7eb6093ca990b71ca9c0127686&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3bf3c7eb6093ca990b71ca9c0127686 = L.map(
#                 &quot;map_a3bf3c7eb6093ca990b71ca9c0127686&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a3bf3c7eb6093ca990b71ca9c0127686);
#
#
#
#
#
#             var tile_layer_ef59f036d95320ddce25f2ecf138c4de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef59f036d95320ddce25f2ecf138c4de.addTo(map_a3bf3c7eb6093ca990b71ca9c0127686);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_a3bf3c7eb6093ca990b71ca9c0127686);
#
#
#
#             var geocoderOpts_geocoder_3cf0aec6360e0c6b4ae2304c51560d6b = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_3cf0aec6360e0c6b4ae2304c51560d6b = geocoderOpts_geocoder_3cf0aec6360e0c6b4ae2304c51560d6b[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_3cf0aec6360e0c6b4ae2304c51560d6b = L.Control.Geocoder[ geocoderName_geocoder_3cf0aec6360e0c6b4ae2304c51560d6b ](
#                 geocoderOpts_geocoder_3cf0aec6360e0c6b4ae2304c51560d6b[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_3cf0aec6360e0c6b4ae2304c51560d6b[&quot;geocoder&quot;] = customGeocoder_geocoder_3cf0aec6360e0c6b4ae2304c51560d6b;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_3cf0aec6360e0c6b4ae2304c51560d6b
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_3cf0aec6360e0c6b4ae2304c51560d6b[&#x27;zoom&#x27;] || map_a3bf3c7eb6093ca990b71ca9c0127686.getZoom();
#                 map_a3bf3c7eb6093ca990b71ca9c0127686.setView(e.geocode.center, zoom);
#             }).addTo(map_a3bf3c7eb6093ca990b71ca9c0127686);
#
#
#
#             map_a3bf3c7eb6093ca990b71ca9c0127686.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_1fd67a8c2f3b80e9733429e15684b074 = L.tileLayer(
#                 &quot;http://localhost:50101/api/tiles/{z}/{x}/{y}.png?\u0026filename=D%3A%5CGit%5Cgeoai%5Cexamples%5CKSARiyadh_PNeo_20210526.tif&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Raster file served by \u003ca href=\u0027https://github.com/banesullivan/localtileserver\u0027 target=\u0027_blank\u0027\u003elocaltileserver\u003c/a\u003e.&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
#   &quot;bounds&quot;: [[24.664562, 46.632771], [24.737867, 46.713101]],
# }
#
#             );
#
#
#             tile_layer_1fd67a8c2f3b80e9733429e15684b074.addTo(map_a3bf3c7eb6093ca990b71ca9c0127686);
#
#
#             map_a3bf3c7eb6093ca990b71ca9c0127686.fitBounds(
#                 [[24.664562, 46.632771], [24.737867, 46.713101]],
#                 {}
#             );
#
#
#             var tile_layer_0d0887c5aea98859738af0ae3b735640 = L.tileLayer(
#                 &quot;http://localhost:50101/api/tiles/{z}/{x}/{y}.png?\u0026filename=D%3A%5CGit%5Cgeoai%5Cexamples%5CKSARiyadh_PNeo_20210526_masks_conf.tif\u0026colormap=tab20&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Raster file served by \u003ca href=\u0027https://github.com/banesullivan/localtileserver\u0027 target=\u0027_blank\u0027\u003elocaltileserver\u003c/a\u003e.&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;:

# %% [markdown]
# ## Vectorize masks

# %%
gdf = geoai.orthogonalize(
    input_path=masks_path, output_path="building_footprints.geojson", epsilon=1.0
)
# Out:
# Processing 1422 features...
# Converting features: 100%|██████████| 1422/1422 [00:42<00:00, 33.31shape/s]
# Saving to building_footprints.geojson...
# Done!

# %% [markdown]
# ## Add geometric attributes

# %%
gdf = geoai.add_geometric_properties(gdf)

# %% [markdown]
# ## Visualize results

# %%
geoai.view_vector_interactive(
    gdf, style_kwds={"color": "red", "fillOpacity": 0.2}, tiles=input_raster
)

# %% [markdown]
# ![image](https://github.com/user-attachments/assets/8c651e7d-b2c3-4bb4-871e-4317cd1444a1)
